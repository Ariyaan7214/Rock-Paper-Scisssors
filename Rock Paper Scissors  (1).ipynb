# %%
#1 = Rock
#2 = Paper
#3 = Scissors

# %% [markdown]
# # Normal Version

# %%
import random
print('Winning rules of the game ROCK PAPER SCISSORS are:\n'
      + "Rock vs Paper -> Paper wins \n"
      + "Rock vs Scissors -> Rock wins \n"
      + "Paper vs Scissors -> Scissors wins \n")
print('Its A Best Of Seven!(Whoever Gets The Most Out Of 7 Plays),'
     +'After 5 Plays Interrupt & ReStart.')



username = input("Enter Your Username: ")


print("Enter your choice \n 1 - Rock \n 2 - Paper \n 3 - Scissors \n")
    
    
choice = int(input("Enter your choice (1-2-3): "))

        
if choice == 1:
    choicename = 'Rock'
elif choice == 2:
    choicename = 'Paper'
else:
    choicename = 'Scissors'
       
        
print('User choice is:', choicename)
print("Now it's Computer's Turn...")
    
    
compchoice = random.randint(1, 3)
    
    
if compchoice == 1:
    compchoicename = 'Rock'
elif compchoice == 2:
    compchoicename = 'Paper'
else:
    compchoicename = 'Scissors'
        
        
print("Computer choice is:", compchoicename)
print(choicename, 'vs', compchoicename)
    
userscore = 0
compscore = 0 



if (choice == 1 and compchoice == 2):
    if userscore == 3:
        print('GAME OVER' + f'{username} Won!' + 'VICTORY')
    elif compscore == 3:
        print('GAME OVER!' + 'Computer Won!' + 'DEFEAT')   
    compscore += 1
    print('Computer Wins!' + f'{userscore} - {compscore}')
        
elif (choice == 1 and compchoice == 3):
    if userscore == 3:               
        print('GAME OVER' + f'{username} Won!' + 'VICTORY')
    elif compscore == 3:
        print('GAME OVER!' + 'Computer Won!' + 'DEFEAT')
    userscore += 1
    print(f'{username} Wins!' + f'{userscore} - {compscore}')
        
elif (choice == 2 and compchoice == 3):
    if userscore == 3:
        print('GAME OVER' + f'{username} Won!' + 'VICTORY')
    elif compscore == 3:
        print('GAME OVER!' + 'Computer Won!' + 'DEFEAT')
    compscore += 1
    print('Computer Wins!' + f'{userscore} - {compscore}')
        
elif (choice == 3 and compchoice == 2):
    if userscore == 3:
        print('GAME OVER' + f'{username} Won!' + 'VICTORY')
    elif compscore == 3:
        print('GAME OVER!' + 'Computer Won!' + 'DEFEAT')
    userscore += 1 
    print(f'{username} Wins!' + f'{userscore} - {compscore}')
        
elif (choice == 2 and compchoice == 1):
    if userscore == 3:
        print('GAME OVER' + f'{username} Won!' + 'VICTORY')
    elif compscore == 3:
        print('GAME OVER!' + 'Computer Won!' + 'DEFEAT')
    userscore += 1
    print(f'{username} Wins!' + f'{userscore} - {compscore}')
        
elif (choice == 3 and compchoice == 1):
    if userscore == 3:
        print('GAME OVER' + f'{username} Won!' + 'VICTORY')
    elif compscore == 3:
        print('GAME OVER!' + 'Computer Won!' + 'DEFEAT')
    compscore += 1
    print('Computer Wins!' + f'{userscore} - {compscore}')
        
elif (choice == 2 and compchoice == 1):
    if userscore == 3:
        print('GAME OVER' + f'{username} Won!' + 'VICTORY')
    elif compscore == 3:
        print('GAME OVER!' + 'Computer Won!' + 'DEFEAT')
    userscore += 1
    print(f'{username} Wins!' + f'{userscore} - {compscore}')
        
elif (choice == 1 and compchoice == 1):
    if userscore == 3:
        print('GAME OVER' + f'{username} Won!' + 'VICTORY')
    elif compscore == 3:
        print('GAME OVER!' + 'Computer Won!' + 'DEFEAT')
    print('Draw.')
    print(f'{userscore} - {compscore}')
        
elif (choice == 2 and compchoice == 2):
    if userscore == 3:
        print('GAME OVER' + f'{username} Won!' + 'VICTORY')
    elif compscore == 3:
        print('GAME OVER!' + 'Computer Won!' + 'DEFEAT')     
    print('Draw.')
    print(f'{userscore} - {compscore}')
        
elif (choice == 3 and compchoice == 3):
    if userscore == 3:
        print('GAME OVER' + f'{username} Won!' + 'VICTORY')
    elif compscore == 3:
        print('GAME OVER!' + 'Computer Won!' + 'DEFEAT')   
    print('Draw.')
    print(f'{userscore} - {compchoice}')
        
else:
    print('Error:404')

    


choice = int(input("Enter your choice (1-2-3): "))

        
if choice == 1:
    choicename = 'Rock'
elif choice == 2:
    choicename = 'Paper'
else:
    choicename = 'Scissors'
       
        
print('User choice is:', choicename)
print("Now it's Computer's Turn...")
    
    
compchoice = random.randint(1, 3)
    
    
if compchoice == 1:
    compchoicename = 'Rock'
elif compchoice == 2:
    compchoicename = 'Paper'
else:
    compchoicename = 'Scissors'
        
        
print("Computer choice is:", compchoicename)
print(choicename, 'vs', compchoicename)
    



if (choice == 1 and compchoice == 2):
    if userscore == 3:
        print('GAME OVER' + f'{username} Won!' + 'VICTORY')
    elif compscore == 3:
        print('GAME OVER!' + 'Computer Won!' + 'DEFEAT')   
    compscore += 1
    print('Computer Wins!' + f'{userscore} - {compscore}')
        
elif (choice == 1 and compchoice == 3):
    if userscore == 3:               
        print('GAME OVER' + f'{username} Won!' + 'VICTORY')
    elif compscore == 3:
        print('GAME OVER!' + 'Computer Won!' + 'DEFEAT')
    userscore += 1
    print(f'{username} Wins!' + f'{userscore} - {compscore}')
        
elif (choice == 2 and compchoice == 3):
    if userscore == 3:
        print('GAME OVER' + f'{username} Won!' + 'VICTORY')
    elif compscore == 3:
        print('GAME OVER!' + 'Computer Won!' + 'DEFEAT')
    compscore += 1
    print('Computer Wins!' + f'{userscore} - {compscore}')
        
elif (choice == 3 and compchoice == 2):
    if userscore == 3:
        print('GAME OVER' + f'{username} Won!' + 'VICTORY')
    elif compscore == 3:
        print('GAME OVER!' + 'Computer Won!' + 'DEFEAT')
    userscore += 1 
    print(f'{username} Wins!' + f'{userscore} - {compscore}')
        
elif (choice == 2 and compchoice == 1):
    if userscore == 3:
        print('GAME OVER' + f'{username} Won!' + 'VICTORY')
    elif compscore == 3:
        print('GAME OVER!' + 'Computer Won!' + 'DEFEAT')
    userscore += 1
    print(f'{username} Wins!' + f'{userscore} - {compscore}')
        
elif (choice == 3 and compchoice == 1):
    if userscore == 3:
        print('GAME OVER' + f'{username} Won!' + 'VICTORY')
    elif compscore == 3:
        print('GAME OVER!' + 'Computer Won!' + 'DEFEAT')
    compscore += 1
    print('Computer Wins!' + f'{userscore} - {compscore}')
        
elif (choice == 2 and compchoice == 1):
    if userscore == 3:
        print('GAME OVER' + f'{username} Won!' + 'VICTORY')
    elif compscore == 3:
        print('GAME OVER!' + 'Computer Won!' + 'DEFEAT')
    userscore += 1
    print(f'{username} Wins!' + f'{userscore} - {compscore}')
        
elif (choice == 1 and compchoice == 1):
    if userscore == 3:
        print('GAME OVER' + f'{username} Won!' + 'VICTORY')
    elif compscore == 3:
        print('GAME OVER!' + 'Computer Won!' + 'DEFEAT')
    print('Draw.')
    print(f'{userscore} - {compscore}')
        
elif (choice == 2 and compchoice == 2):
    if userscore == 3:
        print('GAME OVER' + f'{username} Won!' + 'VICTORY')
    elif compscore == 3:
        print('GAME OVER!' + 'Computer Won!' + 'DEFEAT')     
    print('Draw.')
    print(f'{userscore} - {compscore}')
        
elif (choice == 3 and compchoice == 3):
    if userscore == 3:
        print('GAME OVER' + f'{username} Won!' + 'VICTORY')
    elif compscore == 3:
        print('GAME OVER!' + 'Computer Won!' + 'DEFEAT')   
    print('Draw.')
    print(f'{userscore} - {compchoice}')
        
else:
    print('Error:404')
    
    
choice = int(input("Enter your choice (1-2-3): "))

        
if choice == 1:
    choicename = 'Rock'
elif choice == 2:
    choicename = 'Paper'
else:
    choicename = 'Scissors'
       
        
print('User choice is:', choicename)
print("Now it's Computer's Turn...")
    
    
compchoice = random.randint(1, 3)
    
    
if compchoice == 1:
    compchoicename = 'Rock'
elif compchoice == 2:
    compchoicename = 'Paper'
else:
    compchoicename = 'Scissors'
        
        
print("Computer choice is:", compchoicename)
print(choicename, 'vs', compchoicename)
    



if (choice == 1 and compchoice == 2):
    if userscore == 3:
        print('GAME OVER' + f'{username} Won!' + 'VICTORY')
    elif compscore == 3:
        print('GAME OVER!' + 'Computer Won!' + 'DEFEAT')   
    compscore += 1
    print('Computer Wins!' + f'{userscore} - {compscore}')
        
elif (choice == 1 and compchoice == 3):
    if userscore == 3:               
        print('GAME OVER' + f'{username} Won!' + 'VICTORY')
    elif compscore == 3:
        print('GAME OVER!' + 'Computer Won!' + 'DEFEAT')
    userscore += 1
    print(f'{username} Wins!' + f'{userscore} - {compscore}')
        
elif (choice == 2 and compchoice == 3):
    if userscore == 3:
        print('GAME OVER' + f'{username} Won!' + 'VICTORY')
    elif compscore == 3:
        print('GAME OVER!' + 'Computer Won!' + 'DEFEAT')
    compscore += 1
    print('Computer Wins!' + f'{userscore} - {compscore}')
        
elif (choice == 3 and compchoice == 2):
    if userscore == 3:
        print('GAME OVER' + f'{username} Won!' + 'VICTORY')
    elif compscore == 3:
        print('GAME OVER!' + 'Computer Won!' + 'DEFEAT')
    userscore += 1 
    print(f'{username} Wins!' + f'{userscore} - {compscore}')
        
elif (choice == 2 and compchoice == 1):
    if userscore == 3:
        print('GAME OVER' + f'{username} Won!' + 'VICTORY')
    elif compscore == 3:
        print('GAME OVER!' + 'Computer Won!' + 'DEFEAT')
    userscore += 1
    print(f'{username} Wins!' + f'{userscore} - {compscore}')
        
elif (choice == 3 and compchoice == 1):
    if userscore == 3:
        print('GAME OVER' + f'{username} Won!' + 'VICTORY')
    elif compscore == 3:
        print('GAME OVER!' + 'Computer Won!' + 'DEFEAT')
    compscore += 1
    print('Computer Wins!' + f'{userscore} - {compscore}')
        
elif (choice == 2 and compchoice == 1):
    if userscore == 3:
        print('GAME OVER' + f'{username} Won!' + 'VICTORY')
    elif compscore == 3:
        print('GAME OVER!' + 'Computer Won!' + 'DEFEAT')
    userscore += 1
    print(f'{username} Wins!' + f'{userscore} - {compscore}')
        
elif (choice == 1 and compchoice == 1):
    if userscore == 3:
        print('GAME OVER' + f'{username} Won!' + 'VICTORY')
    elif compscore == 3:
        print('GAME OVER!' + 'Computer Won!' + 'DEFEAT')
    print('Draw.')
    print(f'{userscore} - {compscore}')
        
elif (choice == 2 and compchoice == 2):
    if userscore == 3:
        print('GAME OVER' + f'{username} Won!' + 'VICTORY')
    elif compscore == 3:
        print('GAME OVER!' + 'Computer Won!' + 'DEFEAT')     
    print('Draw.')
    print(f'{userscore} - {compscore}')
        
elif (choice == 3 and compchoice == 3):
    if userscore == 3:
        print('GAME OVER' + f'{username} Won!' + 'VICTORY')
    elif compscore == 3:
        print('GAME OVER!' + 'Computer Won!' + 'DEFEAT')   
    print('Draw.')
    print(f'{userscore} - {compchoice}')
        
else:
    print('Error:404')

    
    
choice = int(input("Enter your choice (1-2-3): "))

        
if choice == 1:
    choicename = 'Rock'
elif choice == 2:
    choicename = 'Paper'
else:
    choicename = 'Scissors'
       
        
print('User choice is:', choicename)
print("Now it's Computer's Turn...")
    
    
compchoice = random.randint(1, 3)
    
    
if compchoice == 1:
    compchoicename = 'Rock'
elif compchoice == 2:
    compchoicename = 'Paper'
else:
    compchoicename = 'Scissors'
        
        
print("Computer choice is:", compchoicename)
print(choicename, 'vs', compchoicename)
    



if (choice == 1 and compchoice == 2):
    if userscore == 3:
        print('GAME OVER' + f'{username} Won!' + 'VICTORY')
    elif compscore == 3:
        print('GAME OVER!' + 'Computer Won!' + 'DEFEAT')   
    compscore += 1
    print('Computer Wins!' + f'{userscore} - {compscore}')
        
elif (choice == 1 and compchoice == 3):
    if userscore == 3:               
        print('GAME OVER' + f'{username} Won!' + 'VICTORY')
    elif compscore == 3:
        print('GAME OVER!' + 'Computer Won!' + 'DEFEAT')
    userscore += 1
    print(f'{username} Wins!' + f'{userscore} - {compscore}')
        
elif (choice == 2 and compchoice == 3):
    if userscore == 3:
        print('GAME OVER' + f'{username} Won!' + 'VICTORY')
    elif compscore == 3:
        print('GAME OVER!' + 'Computer Won!' + 'DEFEAT')
    compscore += 1
    print('Computer Wins!' + f'{userscore} - {compscore}')
        
elif (choice == 3 and compchoice == 2):
    if userscore == 3:
        print('GAME OVER' + f'{username} Won!' + 'VICTORY')
    elif compscore == 3:
        print('GAME OVER!' + 'Computer Won!' + 'DEFEAT')
    userscore += 1 
    print(f'{username} Wins!' + f'{userscore} - {compscore}')
        
elif (choice == 2 and compchoice == 1):
    if userscore == 3:
        print('GAME OVER' + f'{username} Won!' + 'VICTORY')
    elif compscore == 3:
        print('GAME OVER!' + 'Computer Won!' + 'DEFEAT')
    userscore += 1
    print(f'{username} Wins!' + f'{userscore} - {compscore}')
        
elif (choice == 3 and compchoice == 1):
    if userscore == 3:
        print('GAME OVER' + f'{username} Won!' + 'VICTORY')
    elif compscore == 3:
        print('GAME OVER!' + 'Computer Won!' + 'DEFEAT')
    compscore += 1
    print('Computer Wins!' + f'{userscore} - {compscore}')
        
elif (choice == 2 and compchoice == 1):
    if userscore == 3:
        print('GAME OVER' + f'{username} Won!' + 'VICTORY')
    elif compscore == 3:
        print('GAME OVER!' + 'Computer Won!' + 'DEFEAT')
    userscore += 1
    print(f'{username} Wins!' + f'{userscore} - {compscore}')
        
elif (choice == 1 and compchoice == 1):
    if userscore == 3:
        print('GAME OVER' + f'{username} Won!' + 'VICTORY')
    elif compscore == 3:
        print('GAME OVER!' + 'Computer Won!' + 'DEFEAT')
    print('Draw.')
    print(f'{userscore} - {compscore}')
        
elif (choice == 2 and compchoice == 2):
    if userscore == 3:
        print('GAME OVER' + f'{username} Won!' + 'VICTORY')
    elif compscore == 3:
        print('GAME OVER!' + 'Computer Won!' + 'DEFEAT')     
    print('Draw.')
    print(f'{userscore} - {compscore}')
        
elif (choice == 3 and compchoice == 3):
    if userscore == 3:
        print('GAME OVER' + f'{username} Won!' + 'VICTORY')
    elif compscore == 3:
        print('GAME OVER!' + 'Computer Won!' + 'DEFEAT')   
    print('Draw.')
    print(f'{userscore} - {compchoice}')
        
else:
    print('Error:404')
    
    
choice = int(input("Enter your choice (1-2-3): "))

        
if choice == 1:
    choicename = 'Rock'
elif choice == 2:
    choicename = 'Paper'
else:
    choicename = 'Scissors'
       
        
print('User choice is:', choicename)
print("Now it's Computer's Turn...")
    
    
compchoice = random.randint(1, 3)
    
    
if compchoice == 1:
    compchoicename = 'Rock'
elif compchoice == 2:
    compchoicename = 'Paper'
else:
    compchoicename = 'Scissors'
        
        
print("Computer choice is:", compchoicename)
print(choicename, 'vs', compchoicename)
    



if (choice == 1 and compchoice == 2):
    if userscore == 3:
        print('GAME OVER' + f'{username} Won!' + 'VICTORY')
    elif compscore == 3:
        print('GAME OVER!' + 'Computer Won!' + 'DEFEAT')   
    compscore += 1
    print('Computer Wins!' + f'{userscore} - {compscore}')
        
elif (choice == 1 and compchoice == 3):
    if userscore == 3:               
        print('GAME OVER' + f'{username} Won!' + 'VICTORY')
    elif compscore == 3:
        print('GAME OVER!' + 'Computer Won!' + 'DEFEAT')
    userscore += 1
    print(f'{username} Wins!' + f'{userscore} - {compscore}')
        
elif (choice == 2 and compchoice == 3):
    if userscore == 3:
        print('GAME OVER' + f'{username} Won!' + 'VICTORY')
    elif compscore == 3:
        print('GAME OVER!' + 'Computer Won!' + 'DEFEAT')
    compscore += 1
    print('Computer Wins!' + f'{userscore} - {compscore}')
        
elif (choice == 3 and compchoice == 2):
    if userscore == 3:
        print('GAME OVER' + f'{username} Won!' + 'VICTORY')
    elif compscore == 3:
        print('GAME OVER!' + 'Computer Won!' + 'DEFEAT')
    userscore += 1 
    print(f'{username} Wins!' + f'{userscore} - {compscore}')
        
elif (choice == 2 and compchoice == 1):
    if userscore == 3:
        print('GAME OVER' + f'{username} Won!' + 'VICTORY')
    elif compscore == 3:
        print('GAME OVER!' + 'Computer Won!' + 'DEFEAT')
    userscore += 1
    print(f'{username} Wins!' + f'{userscore} - {compscore}')
        
elif (choice == 3 and compchoice == 1):
    if userscore == 3:
        print('GAME OVER' + f'{username} Won!' + 'VICTORY')
    elif compscore == 3:
        print('GAME OVER!' + 'Computer Won!' + 'DEFEAT')
    compscore += 1
    print('Computer Wins!' + f'{userscore} - {compscore}')
        
elif (choice == 2 and compchoice == 1):
    if userscore == 3:
        print('GAME OVER' + f'{username} Won!' + 'VICTORY')
    elif compscore == 3:
        print('GAME OVER!' + 'Computer Won!' + 'DEFEAT')
    userscore += 1
    print(f'{username} Wins!' + f'{userscore} - {compscore}')
        
elif (choice == 1 and compchoice == 1):
    if userscore == 3:
        print('GAME OVER' + f'{username} Won!' + 'VICTORY')
    elif compscore == 3:
        print('GAME OVER!' + 'Computer Won!' + 'DEFEAT')
    print('Draw.')
    print(f'{userscore} - {compscore}')
        
elif (choice == 2 and compchoice == 2):
    if userscore == 3:
        print('GAME OVER' + f'{username} Won!' + 'VICTORY')
    elif compscore == 3:
        print('GAME OVER!' + 'Computer Won!' + 'DEFEAT')     
    print('Draw.')
    print(f'{userscore} - {compscore}')
        
elif (choice == 3 and compchoice == 3):
    if userscore == 3:
        print('GAME OVER' + f'{username} Won!' + 'VICTORY')
    elif compscore == 3:
        print('GAME OVER!' + 'Computer Won!' + 'DEFEAT')   
    print('Draw.')
    print(f'{userscore} - {compchoice}')
        
else:
    print('Error:404')
    
    
choice = int(input("Enter your choice (1-2-3): "))

        
if choice == 1:
    choicename = 'Rock'
elif choice == 2:
    choicename = 'Paper'
else:
    choicename = 'Scissors'
       
        
print('User choice is:', choicename)
print("Now it's Computer's Turn...")
    
    
compchoice = random.randint(1, 3)
    
    
if compchoice == 1:
    compchoicename = 'Rock'
elif compchoice == 2:
    compchoicename = 'Paper'
else:
    compchoicename = 'Scissors'
        
        
print("Computer choice is:", compchoicename)
print(choicename, 'vs', compchoicename)
    



if (choice == 1 and compchoice == 2):
    if userscore == 3:
        print('GAME OVER' + f'{username} Won!' + 'VICTORY')
    elif compscore == 3:
        print('GAME OVER!' + 'Computer Won!' + 'DEFEAT')   
    compscore += 1
    print('Computer Wins!' + f'{userscore} - {compscore}')
        
elif (choice == 1 and compchoice == 3):
    if userscore == 3:               
        print('GAME OVER' + f'{username} Won!' + 'VICTORY')
    elif compscore == 3:
        print('GAME OVER!' + 'Computer Won!' + 'DEFEAT')
    userscore += 1
    print(f'{username} Wins!' + f'{userscore} - {compscore}')
        
elif (choice == 2 and compchoice == 3):
    if userscore == 3:
        print('GAME OVER' + f'{username} Won!' + 'VICTORY')
    elif compscore == 3:
        print('GAME OVER!' + 'Computer Won!' + 'DEFEAT')
    compscore += 1
    print('Computer Wins!' + f'{userscore} - {compscore}')
        
elif (choice == 3 and compchoice == 2):
    if userscore == 3:
        print('GAME OVER' + f'{username} Won!' + 'VICTORY')
    elif compscore == 3:
        print('GAME OVER!' + 'Computer Won!' + 'DEFEAT')
    userscore += 1 
    print(f'{username} Wins!' + f'{userscore} - {compscore}')
        
elif (choice == 2 and compchoice == 1):
    if userscore == 3:
        print('GAME OVER' + f'{username} Won!' + 'VICTORY')
    elif compscore == 3:
        print('GAME OVER!' + 'Computer Won!' + 'DEFEAT')
    userscore += 1
    print(f'{username} Wins!' + f'{userscore} - {compscore}')
        
elif (choice == 3 and compchoice == 1):
    if userscore == 3:
        print('GAME OVER' + f'{username} Won!' + 'VICTORY')
    elif compscore == 3:
        print('GAME OVER!' + 'Computer Won!' + 'DEFEAT')
    compscore += 1
    print('Computer Wins!' + f'{userscore} - {compscore}')
        
elif (choice == 2 and compchoice == 1):
    if userscore == 3:
        print('GAME OVER' + f'{username} Won!' + 'VICTORY')
    elif compscore == 3:
        print('GAME OVER!' + 'Computer Won!' + 'DEFEAT')
    userscore += 1
    print(f'{username} Wins!' + f'{userscore} - {compscore}')
        
elif (choice == 1 and compchoice == 1):
    if userscore == 3:
        print('GAME OVER' + f'{username} Won!' + 'VICTORY')
    elif compscore == 3:
        print('GAME OVER!' + 'Computer Won!' + 'DEFEAT')
    print('Draw.')
    print(f'{userscore} - {compscore}')
        
elif (choice == 2 and compchoice == 2):
    if userscore == 3:
        print('GAME OVER' + f'{username} Won!' + 'VICTORY')
    elif compscore == 3:
        print('GAME OVER!' + 'Computer Won!' + 'DEFEAT')     
    print('Draw.')
    print(f'{userscore} - {compscore}')
        
elif (choice == 3 and compchoice == 3):
    if userscore == 3:
        print('GAME OVER' + f'{username} Won!' + 'VICTORY')
    elif compscore == 3:
        print('GAME OVER!' + 'Computer Won!' + 'DEFEAT')   
    print('Draw.')
    print(f'{userscore} - {compchoice}')
        
else:
    print('Error:404')
        
        

choice = int(input("Enter your choice (1-2-3): "))

        
if choice == 1:
    choicename = 'Rock'
elif choice == 2:
    choicename = 'Paper'
else:
    choicename = 'Scissors'
       
        
print('User choice is:', choicename)
print("Now it's Computer's Turn...")
    
    
compchoice = random.randint(1, 3)
    
    
if compchoice == 1:
    compchoicename = 'Rock'
elif compchoice == 2:
    compchoicename = 'Paper'
else:
    compchoicename = 'Scissors'
        
        
print("Computer choice is:", compchoicename)
print(choicename, 'vs', compchoicename)
    



if (choice == 1 and compchoice == 2):
    if userscore == 3:
        print('GAME OVER' + f'{username} Won!' + 'VICTORY')
    elif compscore == 3:
        print('GAME OVER!' + 'Computer Won!' + 'DEFEAT')   
    compscore += 1
    print('Computer Wins!' + f'{userscore} - {compscore}')
        
elif (choice == 1 and compchoice == 3):
    if userscore == 3:               
        print('GAME OVER' + f'{username} Won!' + 'VICTORY')
    elif compscore == 3:
        print('GAME OVER!' + 'Computer Won!' + 'DEFEAT')
    userscore += 1
    print(f'{username} Wins!' + f'{userscore} - {compscore}')
        
elif (choice == 2 and compchoice == 3):
    if userscore == 3:
        print('GAME OVER' + f'{username} Won!' + 'VICTORY')
    elif compscore == 3:
        print('GAME OVER!' + 'Computer Won!' + 'DEFEAT')
    compscore += 1
    print('Computer Wins!' + f'{userscore} - {compscore}')
        
elif (choice == 3 and compchoice == 2):
    if userscore == 3:
        print('GAME OVER' + f'{username} Won!' + 'VICTORY')
    elif compscore == 3:
        print('GAME OVER!' + 'Computer Won!' + 'DEFEAT')
    userscore += 1 
    print(f'{username} Wins!' + f'{userscore} - {compscore}')
        
elif (choice == 2 and compchoice == 1):
    if userscore == 3:
        print('GAME OVER' + f'{username} Won!' + 'VICTORY')
    elif compscore == 3:
        print('GAME OVER!' + 'Computer Won!' + 'DEFEAT')
    userscore += 1
    print(f'{username} Wins!' + f'{userscore} - {compscore}')
        
elif (choice == 3 and compchoice == 1):
    if userscore == 3:
        print('GAME OVER' + f'{username} Won!' + 'VICTORY')
    elif compscore == 3:
        print('GAME OVER!' + 'Computer Won!' + 'DEFEAT')
    compscore += 1
    print('Computer Wins!' + f'{userscore} - {compscore}')
        
elif (choice == 2 and compchoice == 1):
    if userscore == 3:
        print('GAME OVER' + f'{username} Won!' + 'VICTORY')
    elif compscore == 3:
        print('GAME OVER!' + 'Computer Won!' + 'DEFEAT')
    userscore += 1
    print(f'{username} Wins!' + f'{userscore} - {compscore}')
        
elif (choice == 1 and compchoice == 1):
    if userscore == 3:
        print('GAME OVER' + f'{username} Won!' + 'VICTORY')
    elif compscore == 3:
        print('GAME OVER!' + 'Computer Won!' + 'DEFEAT')
    print('Draw.')
    print(f'{userscore} - {compscore}')
        
elif (choice == 2 and compchoice == 2):
    if userscore == 3:
        print('GAME OVER' + f'{username} Won!' + 'VICTORY')
    elif compscore == 3:
        print('GAME OVER!' + 'Computer Won!' + 'DEFEAT')     
    print('Draw.')
    print(f'{userscore} - {compscore}')
        
elif (choice == 3 and compchoice == 3):
    if userscore == 3:
        print('GAME OVER' + f'{username} Won!' + 'VICTORY')
    elif compscore == 3:
        print('GAME OVER!' + 'Computer Won!' + 'DEFEAT')   
    print('Draw.')
    print(f'{userscore} - {compchoice}')
        
else:
    print('Error:404')
        

    
        

  
    
print("Thanks For Playing!")

# %% [markdown]
# # Def Version

# %%
def rockpaperscissors():
    import random
    print('Winning rules of the game ROCK PAPER SCISSORS are:\n'
          + "Rock vs Paper -> Paper wins \n"
          + "Rock vs Scissors -> Rock wins \n"
          + "Paper vs Scissors -> Scissors wins \n")
    print('Its A Best Of Seven!(Whoever Gets The Most Out Of 7 Plays),'
         +'After 5 Plays Interrupt & ReStart.')



    username = input("Enter Your Username: ")


    print("Enter your choice \n 1 - Rock \n 2 - Paper \n 3 - Scissors \n")


    choice = int(input("Enter your choice (1-2-3): "))


    if choice == 1:
        choicename = 'Rock'
    elif choice == 2:
        choicename = 'Paper'
    else:
        choicename = 'Scissors'


    print('User choice is:', choicename)
    print("Now it's Computer's Turn...")


    compchoice = random.randint(1, 3)


    if compchoice == 1:
        compchoicename = 'Rock'
    elif compchoice == 2:
        compchoicename = 'Paper'
    else:
        compchoicename = 'Scissors'


    print("Computer choice is:", compchoicename)
    print(choicename, 'vs', compchoicename)

    userscore = 0
    compscore = 0 



    if (choice == 1 and compchoice == 2):
        if userscore == 3:
            print('GAME OVER' + f'{username} Won!' + 'VICTORY')
        elif compscore == 3:
            print('GAME OVER!' + 'Computer Won!' + 'DEFEAT')   
        compscore += 1
        print('Computer Wins!' + f'{userscore} - {compscore}')

    elif (choice == 1 and compchoice == 3):
        if userscore == 3:               
            print('GAME OVER' + f'{username} Won!' + 'VICTORY')
        elif compscore == 3:
            print('GAME OVER!' + 'Computer Won!' + 'DEFEAT')
        userscore += 1
        print(f'{username} Wins!' + f'{userscore} - {compscore}')

    elif (choice == 2 and compchoice == 3):
        if userscore == 3:
            print('GAME OVER' + f'{username} Won!' + 'VICTORY')
        elif compscore == 3:
            print('GAME OVER!' + 'Computer Won!' + 'DEFEAT')
        compscore += 1
        print('Computer Wins!' + f'{userscore} - {compscore}')

    elif (choice == 3 and compchoice == 2):
        if userscore == 3:
            print('GAME OVER' + f'{username} Won!' + 'VICTORY')
        elif compscore == 3:
            print('GAME OVER!' + 'Computer Won!' + 'DEFEAT')
        userscore += 1 
        print(f'{username} Wins!' + f'{userscore} - {compscore}')

    elif (choice == 2 and compchoice == 1):
        if userscore == 3:
            print('GAME OVER' + f'{username} Won!' + 'VICTORY')
        elif compscore == 3:
            print('GAME OVER!' + 'Computer Won!' + 'DEFEAT')
        userscore += 1
        print(f'{username} Wins!' + f'{userscore} - {compscore}')

    elif (choice == 3 and compchoice == 1):
        if userscore == 3:
            print('GAME OVER' + f'{username} Won!' + 'VICTORY')
        elif compscore == 3:
            print('GAME OVER!' + 'Computer Won!' + 'DEFEAT')
        compscore += 1
        print('Computer Wins!' + f'{userscore} - {compscore}')

    elif (choice == 2 and compchoice == 1):
        if userscore == 3:
            print('GAME OVER' + f'{username} Won!' + 'VICTORY')
        elif compscore == 3:
            print('GAME OVER!' + 'Computer Won!' + 'DEFEAT')
        userscore += 1
        print(f'{username} Wins!' + f'{userscore} - {compscore}')

    elif (choice == 1 and compchoice == 1):
        if userscore == 3:
            print('GAME OVER' + f'{username} Won!' + 'VICTORY')
        elif compscore == 3:
            print('GAME OVER!' + 'Computer Won!' + 'DEFEAT')
        print('Draw.')
        print(f'{userscore} - {compscore}')

    elif (choice == 2 and compchoice == 2):
        if userscore == 3:
            print('GAME OVER' + f'{username} Won!' + 'VICTORY')
        elif compscore == 3:
            print('GAME OVER!' + 'Computer Won!' + 'DEFEAT')     
        print('Draw.')
        print(f'{userscore} - {compscore}')

    elif (choice == 3 and compchoice == 3):
        if userscore == 3:
            print('GAME OVER' + f'{username} Won!' + 'VICTORY')
        elif compscore == 3:
            print('GAME OVER!' + 'Computer Won!' + 'DEFEAT')   
        print('Draw.')
        print(f'{userscore} - {compchoice}')

    else:
        print('Error:404')




    choice = int(input("Enter your choice (1-2-3): "))


    if choice == 1:
        choicename = 'Rock'
    elif choice == 2:
        choicename = 'Paper'
    else:
        choicename = 'Scissors'


    print('User choice is:', choicename)
    print("Now it's Computer's Turn...")


    compchoice = random.randint(1, 3)


    if compchoice == 1:
        compchoicename = 'Rock'
    elif compchoice == 2:
        compchoicename = 'Paper'
    else:
        compchoicename = 'Scissors'


    print("Computer choice is:", compchoicename)
    print(choicename, 'vs', compchoicename)




    if (choice == 1 and compchoice == 2):
        if userscore == 3:
            print('GAME OVER' + f'{username} Won!' + 'VICTORY')
        elif compscore == 3:
            print('GAME OVER!' + 'Computer Won!' + 'DEFEAT')   
        compscore += 1
        print('Computer Wins!' + f'{userscore} - {compscore}')

    elif (choice == 1 and compchoice == 3):
        if userscore == 3:               
            print('GAME OVER' + f'{username} Won!' + 'VICTORY')
        elif compscore == 3:
            print('GAME OVER!' + 'Computer Won!' + 'DEFEAT')
        userscore += 1
        print(f'{username} Wins!' + f'{userscore} - {compscore}')

    elif (choice == 2 and compchoice == 3):
        if userscore == 3:
            print('GAME OVER' + f'{username} Won!' + 'VICTORY')
        elif compscore == 3:
            print('GAME OVER!' + 'Computer Won!' + 'DEFEAT')
        compscore += 1
        print('Computer Wins!' + f'{userscore} - {compscore}')

    elif (choice == 3 and compchoice == 2):
        if userscore == 3:
            print('GAME OVER' + f'{username} Won!' + 'VICTORY')
        elif compscore == 3:
            print('GAME OVER!' + 'Computer Won!' + 'DEFEAT')
        userscore += 1 
        print(f'{username} Wins!' + f'{userscore} - {compscore}')

    elif (choice == 2 and compchoice == 1):
        if userscore == 3:
            print('GAME OVER' + f'{username} Won!' + 'VICTORY')
        elif compscore == 3:
            print('GAME OVER!' + 'Computer Won!' + 'DEFEAT')
        userscore += 1
        print(f'{username} Wins!' + f'{userscore} - {compscore}')

    elif (choice == 3 and compchoice == 1):
        if userscore == 3:
            print('GAME OVER' + f'{username} Won!' + 'VICTORY')
        elif compscore == 3:
            print('GAME OVER!' + 'Computer Won!' + 'DEFEAT')
        compscore += 1
        print('Computer Wins!' + f'{userscore} - {compscore}')

    elif (choice == 2 and compchoice == 1):
        if userscore == 3:
            print('GAME OVER' + f'{username} Won!' + 'VICTORY')
        elif compscore == 3:
            print('GAME OVER!' + 'Computer Won!' + 'DEFEAT')
        userscore += 1
        print(f'{username} Wins!' + f'{userscore} - {compscore}')

    elif (choice == 1 and compchoice == 1):
        if userscore == 3:
            print('GAME OVER' + f'{username} Won!' + 'VICTORY')
        elif compscore == 3:
            print('GAME OVER!' + 'Computer Won!' + 'DEFEAT')
        print('Draw.')
        print(f'{userscore} - {compscore}')

    elif (choice == 2 and compchoice == 2):
        if userscore == 3:
            print('GAME OVER' + f'{username} Won!' + 'VICTORY')
        elif compscore == 3:
            print('GAME OVER!' + 'Computer Won!' + 'DEFEAT')     
        print('Draw.')
        print(f'{userscore} - {compscore}')

    elif (choice == 3 and compchoice == 3):
        if userscore == 3:
            print('GAME OVER' + f'{username} Won!' + 'VICTORY')
        elif compscore == 3:
            print('GAME OVER!' + 'Computer Won!' + 'DEFEAT')   
        print('Draw.')
        print(f'{userscore} - {compchoice}')

    else:
        print('Error:404')


    choice = int(input("Enter your choice (1-2-3): "))


    if choice == 1:
        choicename = 'Rock'
    elif choice == 2:
        choicename = 'Paper'
    else:
        choicename = 'Scissors'


    print('User choice is:', choicename)
    print("Now it's Computer's Turn...")


    compchoice = random.randint(1, 3)


    if compchoice == 1:
        compchoicename = 'Rock'
    elif compchoice == 2:
        compchoicename = 'Paper'
    else:
        compchoicename = 'Scissors'


    print("Computer choice is:", compchoicename)
    print(choicename, 'vs', compchoicename)




    if (choice == 1 and compchoice == 2):
        if userscore == 3:
            print('GAME OVER' + f'{username} Won!' + 'VICTORY')
        elif compscore == 3:
            print('GAME OVER!' + 'Computer Won!' + 'DEFEAT')   
        compscore += 1
        print('Computer Wins!' + f'{userscore} - {compscore}')

    elif (choice == 1 and compchoice == 3):
        if userscore == 3:               
            print('GAME OVER' + f'{username} Won!' + 'VICTORY')
        elif compscore == 3:
            print('GAME OVER!' + 'Computer Won!' + 'DEFEAT')
        userscore += 1
        print(f'{username} Wins!' + f'{userscore} - {compscore}')

    elif (choice == 2 and compchoice == 3):
        if userscore == 3:
            print('GAME OVER' + f'{username} Won!' + 'VICTORY')
        elif compscore == 3:
            print('GAME OVER!' + 'Computer Won!' + 'DEFEAT')
        compscore += 1
        print('Computer Wins!' + f'{userscore} - {compscore}')

    elif (choice == 3 and compchoice == 2):
        if userscore == 3:
            print('GAME OVER' + f'{username} Won!' + 'VICTORY')
        elif compscore == 3:
            print('GAME OVER!' + 'Computer Won!' + 'DEFEAT')
        userscore += 1 
        print(f'{username} Wins!' + f'{userscore} - {compscore}')

    elif (choice == 2 and compchoice == 1):
        if userscore == 3:
            print('GAME OVER' + f'{username} Won!' + 'VICTORY')
        elif compscore == 3:
            print('GAME OVER!' + 'Computer Won!' + 'DEFEAT')
        userscore += 1
        print(f'{username} Wins!' + f'{userscore} - {compscore}')

    elif (choice == 3 and compchoice == 1):
        if userscore == 3:
            print('GAME OVER' + f'{username} Won!' + 'VICTORY')
        elif compscore == 3:
            print('GAME OVER!' + 'Computer Won!' + 'DEFEAT')
        compscore += 1
        print('Computer Wins!' + f'{userscore} - {compscore}')

    elif (choice == 2 and compchoice == 1):
        if userscore == 3:
            print('GAME OVER' + f'{username} Won!' + 'VICTORY')
        elif compscore == 3:
            print('GAME OVER!' + 'Computer Won!' + 'DEFEAT')
        userscore += 1
        print(f'{username} Wins!' + f'{userscore} - {compscore}')

    elif (choice == 1 and compchoice == 1):
        if userscore == 3:
            print('GAME OVER' + f'{username} Won!' + 'VICTORY')
        elif compscore == 3:
            print('GAME OVER!' + 'Computer Won!' + 'DEFEAT')
        print('Draw.')
        print(f'{userscore} - {compscore}')

    elif (choice == 2 and compchoice == 2):
        if userscore == 3:
            print('GAME OVER' + f'{username} Won!' + 'VICTORY')
        elif compscore == 3:
            print('GAME OVER!' + 'Computer Won!' + 'DEFEAT')     
        print('Draw.')
        print(f'{userscore} - {compscore}')

    elif (choice == 3 and compchoice == 3):
        if userscore == 3:
            print('GAME OVER' + f'{username} Won!' + 'VICTORY')
        elif compscore == 3:
            print('GAME OVER!' + 'Computer Won!' + 'DEFEAT')   
        print('Draw.')
        print(f'{userscore} - {compchoice}')

    else:
        print('Error:404')



    choice = int(input("Enter your choice (1-2-3): "))


    if choice == 1:
        choicename = 'Rock'
    elif choice == 2:
        choicename = 'Paper'
    else:
        choicename = 'Scissors'


    print('User choice is:', choicename)
    print("Now it's Computer's Turn...")


    compchoice = random.randint(1, 3)


    if compchoice == 1:
        compchoicename = 'Rock'
    elif compchoice == 2:
        compchoicename = 'Paper'
    else:
        compchoicename = 'Scissors'


    print("Computer choice is:", compchoicename)
    print(choicename, 'vs', compchoicename)




    if (choice == 1 and compchoice == 2):
        if userscore == 3:
            print('GAME OVER' + f'{username} Won!' + 'VICTORY')
        elif compscore == 3:
            print('GAME OVER!' + 'Computer Won!' + 'DEFEAT')   
        compscore += 1
        print('Computer Wins!' + f'{userscore} - {compscore}')

    elif (choice == 1 and compchoice == 3):
        if userscore == 3:               
            print('GAME OVER' + f'{username} Won!' + 'VICTORY')
        elif compscore == 3:
            print('GAME OVER!' + 'Computer Won!' + 'DEFEAT')
        userscore += 1
        print(f'{username} Wins!' + f'{userscore} - {compscore}')

    elif (choice == 2 and compchoice == 3):
        if userscore == 3:
            print('GAME OVER' + f'{username} Won!' + 'VICTORY')
        elif compscore == 3:
            print('GAME OVER!' + 'Computer Won!' + 'DEFEAT')
        compscore += 1
        print('Computer Wins!' + f'{userscore} - {compscore}')

    elif (choice == 3 and compchoice == 2):
        if userscore == 3:
            print('GAME OVER' + f'{username} Won!' + 'VICTORY')
        elif compscore == 3:
            print('GAME OVER!' + 'Computer Won!' + 'DEFEAT')
        userscore += 1 
        print(f'{username} Wins!' + f'{userscore} - {compscore}')

    elif (choice == 2 and compchoice == 1):
        if userscore == 3:
            print('GAME OVER' + f'{username} Won!' + 'VICTORY')
        elif compscore == 3:
            print('GAME OVER!' + 'Computer Won!' + 'DEFEAT')
        userscore += 1
        print(f'{username} Wins!' + f'{userscore} - {compscore}')

    elif (choice == 3 and compchoice == 1):
        if userscore == 3:
            print('GAME OVER' + f'{username} Won!' + 'VICTORY')
        elif compscore == 3:
            print('GAME OVER!' + 'Computer Won!' + 'DEFEAT')
        compscore += 1
        print('Computer Wins!' + f'{userscore} - {compscore}')

    elif (choice == 2 and compchoice == 1):
        if userscore == 3:
            print('GAME OVER' + f'{username} Won!' + 'VICTORY')
        elif compscore == 3:
            print('GAME OVER!' + 'Computer Won!' + 'DEFEAT')
        userscore += 1
        print(f'{username} Wins!' + f'{userscore} - {compscore}')

    elif (choice == 1 and compchoice == 1):
        if userscore == 3:
            print('GAME OVER' + f'{username} Won!' + 'VICTORY')
        elif compscore == 3:
            print('GAME OVER!' + 'Computer Won!' + 'DEFEAT')
        print('Draw.')
        print(f'{userscore} - {compscore}')

    elif (choice == 2 and compchoice == 2):
        if userscore == 3:
            print('GAME OVER' + f'{username} Won!' + 'VICTORY')
        elif compscore == 3:
            print('GAME OVER!' + 'Computer Won!' + 'DEFEAT')     
        print('Draw.')
        print(f'{userscore} - {compscore}')

    elif (choice == 3 and compchoice == 3):
        if userscore == 3:
            print('GAME OVER' + f'{username} Won!' + 'VICTORY')
        elif compscore == 3:
            print('GAME OVER!' + 'Computer Won!' + 'DEFEAT')   
        print('Draw.')
        print(f'{userscore} - {compchoice}')

    else:
        print('Error:404')


    choice = int(input("Enter your choice (1-2-3): "))


    if choice == 1:
        choicename = 'Rock'
    elif choice == 2:
        choicename = 'Paper'
    else:
        choicename = 'Scissors'


    print('User choice is:', choicename)
    print("Now it's Computer's Turn...")


    compchoice = random.randint(1, 3)


    if compchoice == 1:
        compchoicename = 'Rock'
    elif compchoice == 2:
        compchoicename = 'Paper'
    else:
        compchoicename = 'Scissors'


    print("Computer choice is:", compchoicename)
    print(choicename, 'vs', compchoicename)




    if (choice == 1 and compchoice == 2):
        if userscore == 3:
            print('GAME OVER' + f'{username} Won!' + 'VICTORY')
        elif compscore == 3:
            print('GAME OVER!' + 'Computer Won!' + 'DEFEAT')   
        compscore += 1
        print('Computer Wins!' + f'{userscore} - {compscore}')

    elif (choice == 1 and compchoice == 3):
        if userscore == 3:               
            print('GAME OVER' + f'{username} Won!' + 'VICTORY')
        elif compscore == 3:
            print('GAME OVER!' + 'Computer Won!' + 'DEFEAT')
        userscore += 1
        print(f'{username} Wins!' + f'{userscore} - {compscore}')

    elif (choice == 2 and compchoice == 3):
        if userscore == 3:
            print('GAME OVER' + f'{username} Won!' + 'VICTORY')
        elif compscore == 3:
            print('GAME OVER!' + 'Computer Won!' + 'DEFEAT')
        compscore += 1
        print('Computer Wins!' + f'{userscore} - {compscore}')

    elif (choice == 3 and compchoice == 2):
        if userscore == 3:
            print('GAME OVER' + f'{username} Won!' + 'VICTORY')
        elif compscore == 3:
            print('GAME OVER!' + 'Computer Won!' + 'DEFEAT')
        userscore += 1 
        print(f'{username} Wins!' + f'{userscore} - {compscore}')

    elif (choice == 2 and compchoice == 1):
        if userscore == 3:
            print('GAME OVER' + f'{username} Won!' + 'VICTORY')
        elif compscore == 3:
            print('GAME OVER!' + 'Computer Won!' + 'DEFEAT')
        userscore += 1
        print(f'{username} Wins!' + f'{userscore} - {compscore}')

    elif (choice == 3 and compchoice == 1):
        if userscore == 3:
            print('GAME OVER' + f'{username} Won!' + 'VICTORY')
        elif compscore == 3:
            print('GAME OVER!' + 'Computer Won!' + 'DEFEAT')
        compscore += 1
        print('Computer Wins!' + f'{userscore} - {compscore}')

    elif (choice == 2 and compchoice == 1):
        if userscore == 3:
            print('GAME OVER' + f'{username} Won!' + 'VICTORY')
        elif compscore == 3:
            print('GAME OVER!' + 'Computer Won!' + 'DEFEAT')
        userscore += 1
        print(f'{username} Wins!' + f'{userscore} - {compscore}')

    elif (choice == 1 and compchoice == 1):
        if userscore == 3:
            print('GAME OVER' + f'{username} Won!' + 'VICTORY')
        elif compscore == 3:
            print('GAME OVER!' + 'Computer Won!' + 'DEFEAT')
        print('Draw.')
        print(f'{userscore} - {compscore}')

    elif (choice == 2 and compchoice == 2):
        if userscore == 3:
            print('GAME OVER' + f'{username} Won!' + 'VICTORY')
        elif compscore == 3:
            print('GAME OVER!' + 'Computer Won!' + 'DEFEAT')     
        print('Draw.')
        print(f'{userscore} - {compscore}')

    elif (choice == 3 and compchoice == 3):
        if userscore == 3:
            print('GAME OVER' + f'{username} Won!' + 'VICTORY')
        elif compscore == 3:
            print('GAME OVER!' + 'Computer Won!' + 'DEFEAT')   
        print('Draw.')
        print(f'{userscore} - {compchoice}')

    else:
        print('Error:404')


    choice = int(input("Enter your choice (1-2-3): "))


    if choice == 1:
        choicename = 'Rock'
    elif choice == 2:
        choicename = 'Paper'
    else:
        choicename = 'Scissors'


    print('User choice is:', choicename)
    print("Now it's Computer's Turn...")


    compchoice = random.randint(1, 3)


    if compchoice == 1:
        compchoicename = 'Rock'
    elif compchoice == 2:
        compchoicename = 'Paper'
    else:
        compchoicename = 'Scissors'


    print("Computer choice is:", compchoicename)
    print(choicename, 'vs', compchoicename)




    if (choice == 1 and compchoice == 2):
        if userscore == 3:
            print('GAME OVER' + f'{username} Won!' + 'VICTORY')
        elif compscore == 3:
            print('GAME OVER!' + 'Computer Won!' + 'DEFEAT')   
        compscore += 1
        print('Computer Wins!' + f'{userscore} - {compscore}')

    elif (choice == 1 and compchoice == 3):
        if userscore == 3:               
            print('GAME OVER' + f'{username} Won!' + 'VICTORY')
        elif compscore == 3:
            print('GAME OVER!' + 'Computer Won!' + 'DEFEAT')
        userscore += 1
        print(f'{username} Wins!' + f'{userscore} - {compscore}')

    elif (choice == 2 and compchoice == 3):
        if userscore == 3:
            print('GAME OVER' + f'{username} Won!' + 'VICTORY')
        elif compscore == 3:
            print('GAME OVER!' + 'Computer Won!' + 'DEFEAT')
        compscore += 1
        print('Computer Wins!' + f'{userscore} - {compscore}')

    elif (choice == 3 and compchoice == 2):
        if userscore == 3:
            print('GAME OVER' + f'{username} Won!' + 'VICTORY')
        elif compscore == 3:
            print('GAME OVER!' + 'Computer Won!' + 'DEFEAT')
        userscore += 1 
        print(f'{username} Wins!' + f'{userscore} - {compscore}')

    elif (choice == 2 and compchoice == 1):
        if userscore == 3:
            print('GAME OVER' + f'{username} Won!' + 'VICTORY')
        elif compscore == 3:
            print('GAME OVER!' + 'Computer Won!' + 'DEFEAT')
        userscore += 1
        print(f'{username} Wins!' + f'{userscore} - {compscore}')

    elif (choice == 3 and compchoice == 1):
        if userscore == 3:
            print('GAME OVER' + f'{username} Won!' + 'VICTORY')
        elif compscore == 3:
            print('GAME OVER!' + 'Computer Won!' + 'DEFEAT')
        compscore += 1
        print('Computer Wins!' + f'{userscore} - {compscore}')

    elif (choice == 2 and compchoice == 1):
        if userscore == 3:
            print('GAME OVER' + f'{username} Won!' + 'VICTORY')
        elif compscore == 3:
            print('GAME OVER!' + 'Computer Won!' + 'DEFEAT')
        userscore += 1
        print(f'{username} Wins!' + f'{userscore} - {compscore}')

    elif (choice == 1 and compchoice == 1):
        if userscore == 3:
            print('GAME OVER' + f'{username} Won!' + 'VICTORY')
        elif compscore == 3:
            print('GAME OVER!' + 'Computer Won!' + 'DEFEAT')
        print('Draw.')
        print(f'{userscore} - {compscore}')

    elif (choice == 2 and compchoice == 2):
        if userscore == 3:
            print('GAME OVER' + f'{username} Won!' + 'VICTORY')
        elif compscore == 3:
            print('GAME OVER!' + 'Computer Won!' + 'DEFEAT')     
        print('Draw.')
        print(f'{userscore} - {compscore}')

    elif (choice == 3 and compchoice == 3):
        if userscore == 3:
            print('GAME OVER' + f'{username} Won!' + 'VICTORY')
        elif compscore == 3:
            print('GAME OVER!' + 'Computer Won!' + 'DEFEAT')   
        print('Draw.')
        print(f'{userscore} - {compchoice}')

    else:
        print('Error:404')



    choice = int(input("Enter your choice (1-2-3): "))


    if choice == 1:
        choicename = 'Rock'
    elif choice == 2:
        choicename = 'Paper'
    else:
        choicename = 'Scissors'


    print('User choice is:', choicename)
    print("Now it's Computer's Turn...")


    compchoice = random.randint(1, 3)


    if compchoice == 1:
        compchoicename = 'Rock'
    elif compchoice == 2:
        compchoicename = 'Paper'
    else:
        compchoicename = 'Scissors'


    print("Computer choice is:", compchoicename)
    print(choicename, 'vs', compchoicename)




    if (choice == 1 and compchoice == 2):
        if userscore == 3:
            print('GAME OVER' + f'{username} Won!' + 'VICTORY')
        elif compscore == 3:
            print('GAME OVER!' + 'Computer Won!' + 'DEFEAT')   
        compscore += 1
        print('Computer Wins!' + f'{userscore} - {compscore}')

    elif (choice == 1 and compchoice == 3):
        if userscore == 3:               
            print('GAME OVER' + f'{username} Won!' + 'VICTORY')
        elif compscore == 3:
            print('GAME OVER!' + 'Computer Won!' + 'DEFEAT')
        userscore += 1
        print(f'{username} Wins!' + f'{userscore} - {compscore}')

    elif (choice == 2 and compchoice == 3):
        if userscore == 3:
            print('GAME OVER' + f'{username} Won!' + 'VICTORY')
        elif compscore == 3:
            print('GAME OVER!' + 'Computer Won!' + 'DEFEAT')
        compscore += 1
        print('Computer Wins!' + f'{userscore} - {compscore}')

    elif (choice == 3 and compchoice == 2):
        if userscore == 3:
            print('GAME OVER' + f'{username} Won!' + 'VICTORY')
        elif compscore == 3:
            print('GAME OVER!' + 'Computer Won!' + 'DEFEAT')
        userscore += 1 
        print(f'{username} Wins!' + f'{userscore} - {compscore}')

    elif (choice == 2 and compchoice == 1):
        if userscore == 3:
            print('GAME OVER' + f'{username} Won!' + 'VICTORY')
        elif compscore == 3:
            print('GAME OVER!' + 'Computer Won!' + 'DEFEAT')
        userscore += 1
        print(f'{username} Wins!' + f'{userscore} - {compscore}')

    elif (choice == 3 and compchoice == 1):
        if userscore == 3:
            print('GAME OVER' + f'{username} Won!' + 'VICTORY')
        elif compscore == 3:
            print('GAME OVER!' + 'Computer Won!' + 'DEFEAT')
        compscore += 1
        print('Computer Wins!' + f'{userscore} - {compscore}')

    elif (choice == 2 and compchoice == 1):
        if userscore == 3:
            print('GAME OVER' + f'{username} Won!' + 'VICTORY')
        elif compscore == 3:
            print('GAME OVER!' + 'Computer Won!' + 'DEFEAT')
        userscore += 1
        print(f'{username} Wins!' + f'{userscore} - {compscore}')

    elif (choice == 1 and compchoice == 1):
        if userscore == 3:
            print('GAME OVER' + f'{username} Won!' + 'VICTORY')
        elif compscore == 3:
            print('GAME OVER!' + 'Computer Won!' + 'DEFEAT')
        print('Draw.')
        print(f'{userscore} - {compscore}')

    elif (choice == 2 and compchoice == 2):
        if userscore == 3:
            print('GAME OVER' + f'{username} Won!' + 'VICTORY')
        elif compscore == 3:
            print('GAME OVER!' + 'Computer Won!' + 'DEFEAT')     
        print('Draw.')
        print(f'{userscore} - {compscore}')

    elif (choice == 3 and compchoice == 3):
        if userscore == 3:
            print('GAME OVER' + f'{username} Won!' + 'VICTORY')
        elif compscore == 3:
            print('GAME OVER!' + 'Computer Won!' + 'DEFEAT')   
        print('Draw.')
        print(f'{userscore} - {compchoice}')

    else:
        print('Error:404')







    print("Thanks For Playing!")
